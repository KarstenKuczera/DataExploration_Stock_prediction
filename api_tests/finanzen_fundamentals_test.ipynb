# %% [markdown]
# # Finanzen_fundamentals Test
#
# [comment]: <> (https://github.com/Jhruzik/Finanzen-Fundamentals)

# %% [markdown]
# #### Vorteile
# * Bringt viele Informationen zu den einzelnen Unternehmen
#     * Informationen können in die Vorhersagenbewertung mit einfließen
# * Ausgaben auch oft in DataFrames möglich
# * Außer Aktien gibt es auch noch andere Anlageformen
#
# #### Nachteile
# * Bringt nur den Aktuellen Preis der Aktie

# %%
import finanzen_fundamentals.stocks as stocks
import finanzen_fundamentals.funds as funds
import finanzen_fundamentals.etfs as etfs
import finanzen_fundamentals.commodities as commodities

# %%
stocks.search_stock("BMW", limit=3)
#funds.search_fund("Private Equity", limit=10)
#etfs.search_etf("iShares", limit=10)
#commodities.search_commodity("Kohle", limit=3)
# Out:
# [{'Name': 'BMW AG',
#   'Stock': 'bmw-aktie',
#   'Link': 'https://www.finanzen.net/aktien/bmw-aktie',
#   'ISIN': 'DE0005190003',
#   'WKN': '519000'},
#  {'Name': 'BMW Vz.',
#   'Stock': 'bmw_vz-aktie',
#   'Link': 'https://www.finanzen.net/aktien/bmw_vz-aktie',
#   'ISIN': 'DE0005190037',
#   'WKN': '519003'},
#  {'Name': 'BMW Industries Ltd Registered Shs',
#   'Stock': 'bmw_industries-aktie',
#   'Link': 'https://www.finanzen.net/aktien/bmw_industries-aktie',
#   'ISIN': 'INE374E01021',
#   'WKN': None}]

# %%
stocks.get_fundamentals("basf-aktie").drop_duplicates(subset=["Metric"])
#etfs.get_info("ishares-core-msci-world-etf-ie00b4l5y983")
#funds.get_info("schroder-international-selection-fund-inflation-plus-a-lu0107768052")
#commodities.get_info("kohlepreis")
# Out:
# c:\Users\K.Kuczera\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            Category                                          Metric  Year  \
# 0            Quotes  Ergebnis je Aktie (unverwässert, nach Steuern)  2015
# 0            Quotes    Ergebnis je Aktie (verwässert, nach Steuern)  2015
# 0            Quotes                              Dividende je Aktie  2015
# 0            Quotes            Gesamtdividendenausschüttung in Mio.  2015
# 0        Key Ratios                                 Umsatz je Aktie  2015
# 0        Key Ratios                             KGV (Jahresendkurs)  2015
# 0        Key Ratios             KGV (Jahresendkurs, EPS verwässert)  2015
# 0        Key Ratios               Dividendenrendite Jahresende in %  2015
# 0        Key Ratios                          Eigenkapitalquote in %  2015
# 0        Key Ratios                          Fremdkapitalquote in %  2015
# 0  Income Statement                                    Umsatzerlöse  2015
# 0  Income Statement                          Umsatzveränderung in %  2015
# 0  Income Statement                       Bruttoergebnis vom Umsatz  2015
# 0  Income Statement                  Bruttoergebnisveränderung in %  2015
# 0  Income Statement                             Operatives Ergebnis  2015
# 0  Income Statement            Veränderung Operatives Ergebnis in %  2015
# 0  Income Statement                            Ergebnis vor Steuern  2015
# 0  Income Statement           Veränderung Ergebnis vor Steuern in %  2015
# 0  Income Statement                            Ergebnis nach Steuer  2015
# 0  Income Statement           Veränderung Ergebnis nach Steuer in %  2015
# 0     Balance Sheet                         Gesamtverbindlichkeiten  2015
# 0     Balance Sheet          Langzeit Gesamtverbindlichk. pro Aktie  2015
# 0     Balance Sheet                                    Eigenkapital  2015
# 0     Balance Sheet                   Veränderung Eigenkapital in %  2015
# 0     Balance Sheet                                     Bilanzsumme  2015
# 0     Balance Sheet                    Veränderung Bilanzsumme in %  2015
# 0             Other    Gewinn je Aktie (unverwässert, nach Steuern)  2015
# 0             Other             Veränderung EPS (unverwässert) in %  2015
# 0             Other      Gewinn je Aktie (verwässert, nach Steuern)  2015
# 0             Other               Veränderung EPS (verwässert) in %  2015
# 0             Other             Veränderung Dividende je Aktie in %  2015
# 0             Other                              Anzahl Mitarbeiter  2015
# 0             Other             Veränderung Anzahl Mitarbeiter in %  2015
#
#        Value
# 0       4.34
# 0       4.33
# 0       2.90
# 0    2572.00
# 0      76.51
# 0      16.29
# 0      16.33
# 0       4.10
# 0      41.94
# 0      57.20
# 0   70449.00
# 0      -5.22
# 0   18207.00
# 0      -0.72
# 0    6125.00
# 0     -14.80
# 0    5297.00
# 0     -23.56
# 0    3987.00
# 0     -22.66
# 0   42164.00
# 0      30.13
# 0   31545.00
# 0      11.96
# 0   73709.00
# 0      -1.09
# 0       4.34
# 0     -22.64
# 0       4.33
# 0     -22.68
# 0       3.57
# 0  112435.00
# 0      -0.76

# %%
#stocks.get_fundamentals(stock="lufthansa-aktie", output="dict")
etfs.get_info(etf="ishares-core-msci-world-etf-ie00b4l5y983", output="dict")
#funds.get_info(fund="schroder-international-selection-fund-inflation-plus-a-lu0107768052", output="dict")
#commodities.get_info("kohlepreis", output="dict")
# Out:
# c:\Users\K.Kuczera\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'ETF': 'ishares-core-msci-world-etf-ie00b4l5y983',
#  'WKN': 'A0RPWH',
#  'ISIN': 'IE00B4L5Y983',
#  'Issuer': 'BlackRock Asset Management - ETF',
#  'Issue Date': datetime.datetime(2009, 9, 25, 0, 0),
#  'Category': 'Aktien',
#  'Currency': 'USD',
#  'Benchmark': 'MSCI World',
#  'Distribution': 'Thesaurierend',
#  'Expense Ratio': 0.2,
#  'Volume': 41603276645.36,
#  'Replication': 'Physisch optimiert'}

# %%
stocks.get_estimates(stock="lufthansa-aktie")
# Out:
#                   Metric   Year     Value
# 0   Umsatzerlöse in Mio.  2022e  29218.50
# 1   Umsatzerlöse in Mio.  2023e  33981.42
# 2   Umsatzerlöse in Mio.  2024e  37162.66
# 3   Umsatzerlöse in Mio.  2025e  38501.11
# 4   Umsatzerlöse in Mio.  2026e  37773.00
# ..                   ...    ...       ...
# 0    Bilanzsumme in Mio.  2022e  43864.25
# 1    Bilanzsumme in Mio.  2023e  44439.50
# 2    Bilanzsumme in Mio.  2024e  44586.00
# 3    Bilanzsumme in Mio.  2025e  43848.50
# 4    Bilanzsumme in Mio.  2026e  43492.00
#
# [95 rows x 3 columns]

# %%
#stocks.get_price(stock="lufthansa-aktie", exchange="FSE")
etfs.get_price(etf="ishares-core-msci-world-etf-ie00b4l5y983", exchange="FSE")
#funds.get_price(fund="schroder-international-selection-fund-inflation-plus-a-lu0107768052", exchange="FSE")
#commodities.get_price(commodity="kohlepreis", currency="USD")
# Out:
# c:\Users\K.Kuczera\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Price Currency           Timestamp  \
# 0  72.46      EUR 2022-06-07 10:09:17
#
#                                         ETF Exchange
# 0  ishares-core-msci-world-etf-ie00b4l5y983      FSE

# %%
#stocks.get_price(stock="lufthansa-aktie", exchange="FSE", output="dict")
etfs.get_price(etf="ishares-core-msci-world-etf-ie00b4l5y983",
	       exchange="FSE", output="dict")
#funds.get_price(fund="schroder-international-selection-fund-inflation-plus-a-lu0107768052",
		#exchange="FSE", output="dict")
#commodities.get_price(commodity="kohlepreis", currency="USD", output="dict")
# Out:
# c:\Users\K.Kuczera\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'Price': 72.46,
#  'Currency': 'EUR',
#  'Timestamp': datetime.datetime(2022, 6, 7, 10, 9, 17),
#  'ETF': 'ishares-core-msci-world-etf-ie00b4l5y983',
#  'Exchange': 'FSE'}
