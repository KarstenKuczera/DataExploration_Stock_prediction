# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.25,rc={'figure.figsize':(10,8)})

# %%
# LS1 Epoch 50, 500, 1000   LS15 Epoch 50, 500, 1000
teamviewer_mae = [10.70215, 10.21513, 10.27809, 12.25330, 10.55078, 10.14609]
teamviewer_acc = [0.46564, 0.51908, 0.58015, 0.46875, 0.90625, 0.94531]
teamviewer_mean_profit = [-0.03019, 0.07097, 0.16084, 0.09316, 2.74531, 2.57218]
teamviewer_sum_profit = [-3.95502, 9.29799, 21.07101, 11.92498, 351.4, 329.24]

amazon_mae = [0.86086, 0.56768, 0.60989, 1.77247, 1.50944, 1.44924]
amazon_acc = [0.51235, 0.50278, 0.51792, 0.568, 0.58339, 0.56344]
amazon_mean_profit = [0.05064, -0.01529, 0.07832, 0.60678, 0.84586, 0.91337]
amazon_sum_profit = [63.56424, -19.19082, 98.30275, 758.48202, 1059.86880, 1144.45671]

# %%
columns_epochs = ["50", "500", "1000"]

fig, ax = plt.subplots()
bars = ax.bar(columns_epochs, teamviewer_acc[0:3])

ax.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4e949b99624a> in <module>
#       4 bars = ax.barh(columns_epochs, teamviewer_acc[0:3])
#       5
# ----> 6 ax.bar_label(bars)
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'
